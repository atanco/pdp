# %%
# %matplotlib inline
import math
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt

from collections import defaultdict
from scipy.stats.stats import pearsonr

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/Buraz/return.csv")
dfv=pd.read_csv("/content/drive/MyDrive/Buraz/volatility2 (1).csv")

# %%
columnr=[]
for col in df.columns:
    columnr+=[col]

columnv=[]
for col in dfv.columns:
    columnv+=[col]

# %%
for col in columnr:
  ts = df[col]
  plt.plot(ts)
  plt.title(col)
  name=col+'.png'
  plt.savefig(name, format="png")
  plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
for col in columnv:
  ts = dfv[col]
  plt.plot(ts, color='r')
  plt.title(col)
  name='r-'+col+'.png'
  plt.savefig(name, format="png")
  plt.show()

# %%
df = df.iloc[:-1 , :]

# %%
plt.scatter(dfv['DCA-YES'], df['DCA-REB-12M'], color='g')

plt.show()

# %%
columnr

# %%
columnv

# %%
df=pd.read_csv("/content/drive/MyDrive/Buraz/1-OFF_Best_results.csv")

# %%
ts = df['Return Value']
plt.plot(ts)
plt.title('Return Value')
plt.show()

# %%
df=pd.read_csv("/content/drive/MyDrive/Buraz/1-OFF_Best_results_3M.csv")
